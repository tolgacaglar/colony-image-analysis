# %% [markdown]
# # Analysis of the boxfiltered image data
# - Preprocessing is complete, then now, obtain the thresholded binary image
# - Threshold is obtained from the maximum count of the boxfiltered image

# %% [markdown]
# ## First, test for a chosen tstr, zstr boxfiltered image

# %%
# %matplotlib notebook

# Dependencies
import pandas as pd
import numpy as np
import xml.etree.ElementTree as ET
import cv2
import colony_iomethods as cm

from matplotlib import pyplot as plt

# %%
# Obtain the folder properties:
folder = "D:/Tolga/Colony Images/"
exp_name = "EQ59_Single_Colony_TilesScan.lif"

# Read the combined csv
combined_df = pd.read_csv(folder + exp_name + "/" + exp_name + "_combined.csv", index_col="Tp_id")
# Drop the NAN values
combined_df.dropna(inplace = True)
# Reorder in ascending time
combined_df.sort_values(by="time", ascending=True, inplace=True)
combined_df.iloc[6:]
# Out:
#        tix  plate_id       time            comment  max_filtered_counts  \
# Tp_id
# 7        6         2  16.866667  TileScan init_12h                   10
# 8        7         2  17.366667  TileScan init_12h                   12
# 9        8         2  17.866667  TileScan init_12h                    0
# 10       0         2  18.816667  TileScan long_24h                   18
# 11       1         2  19.316667  TileScan long_24h                   21
# 12       2         2  19.816667  TileScan long_24h                   21
# 13       3         2  20.316667  TileScan long_24h                   18
# 14       4         2  20.816667  TileScan long_24h                   17
# 15       5         2  21.316667  TileScan long_24h                   17
# 16       6         2  21.816667  TileScan long_24h                   16
# 17       7         2  22.316667  TileScan long_24h                   19
# 18       8         2  22.816667  TileScan long_24h                   17
# 19       9         2  23.316667  TileScan long_24h                   18
# 20      10         2  23.816667  TileScan long_24h                   17
# 21      11         2  24.316667  TileScan long_24h                   18
# 22      12         2  24.816667  TileScan long_24h                   16
# 23      13         2  25.316667  TileScan long_24h                   16
# 24      14         2  25.816667  TileScan long_24h                   18
# 25      15         2  26.316667  TileScan long_24h                   19
# 26      16         2  26.816667  TileScan long_24h                   18
# 27      17         2  27.316667  TileScan long_24h                   19
# 28      18         2  27.816667  TileScan long_24h                   18
# 29      19         2  28.316667  TileScan long_24h                   16
# 30      20         2  28.816667  TileScan long_24h                   17
# 31      21         2  29.316667  TileScan long_24h                   17
# 32      22         2  29.816667  TileScan long_24h                   19
# 33      23         2  30.316667  TileScan long_24h                   19
# 34      24         2  30.816667  TileScan long_24h                   18
# 35      25         2  31.316667  TileScan long_24h                   17
# 36      26         2  31.816667  TileScan long_24h                   20
# 37      27         2  32.316667  TileScan long_24h                   20
# 38      28         2  32.816667  TileScan long_24h                   18
# 39      29         2  33.316667  TileScan long_24h                   22
# 40      30         2  33.816667  TileScan long_24h                   20
# 41      31         2  34.316667  TileScan long_24h                   19
# 42      32         2  34.816667  TileScan long_24h                   19
# 43      33         2  35.316667  TileScan long_24h                   20
# 44      34         2  35.816667  TileScan long_24h                   20
# 45      35         2  36.316667  TileScan long_24h                   18
# 46      36         2  36.816667  TileScan long_24h                   19
# 47      37         2  37.316667  TileScan long_24h                   19
# 48      38         2  37.816667  TileScan long_24h                   17
# 49      39         2  38.316667  TileScan long_24h                   18
# 50      40         2  38.816667  TileScan long_24h                   19
# 51      41         2  39.316667  TileScan long_24h                   18
# 52      42         2  39.816667  TileScan long_24h                   19
# 53      43         2  40.316667  TileScan long_24h                   18
# 54      44         2  40.816667  TileScan long_24h                   18
# 55      45         2  41.316667  TileScan long_24h                   22
# 56      46         2  41.816667  TileScan long_24h                   17
# 57      47         2  42.316667  TileScan long_24h                   19
# 58      48         2  42.816667  TileScan long_24h                   18
#
#        average_counts                                           acq_name  \
# Tp_id
# 7            0.081134  EQ59_Single_Colony_TilesScan.lif_3dTimeScan_12...
# 8            0.094280  EQ59_Single_Colony_TilesScan.lif_3dTimeScan_12...
# 9            0.000000  EQ59_Single_Colony_TilesScan.lif_3dTimeScan_12...
# 10           0.212287  EQ59_Single_Colony_TilesScan.lif_3dTimeScan_17...
# 11           0.229717  EQ59_Single_Colony_TilesScan.lif_3dTimeScan_17...
# 12           0.244964  EQ59_Single_Colony_TilesScan.lif_3dTimeScan_17...
# 13           0.254540  EQ59_Single_Colony_TilesScan.lif_3dTimeScan_17...
# 14           0.265953  EQ59_Single_Colony_TilesScan.lif_3dTimeScan_17...
# 15           0.277742  EQ59_Single_Colony_TilesScan.lif_3dTimeScan_17...
# 16           0.289922  EQ59_Single_Colony_TilesScan.lif_3dTimeScan_17...
# 17           0.301257  EQ59_Single_Colony_TilesScan.lif_3dTimeScan_17...
# 18           0.312127  EQ59_Single_Colony_TilesScan.lif_3dTimeScan_17...
# 19           0.324460  EQ59_Single_Colony_TilesScan.lif_3dTimeScan_17...
# 20           0.330127  EQ59_Single_Colony_TilesScan.lif_3dTimeScan_17...
# 21           0.347518  EQ59_Single_Colony_TilesScan.lif_3dTimeScan_17...
# 22           0.356517  EQ59_Single_Colony_TilesScan.lif_3dTimeScan_17...
# 23           0.360891  EQ59_Single_Colony_TilesScan.lif_3dTimeScan_17...
# 24           0.373792  EQ59_Single_Colony_TilesScan.lif_3dTimeScan_17...
# 25           0.393763  EQ59_Single_Colony_TilesScan.lif_3dTimeScan_17...
# 26           0.406227  EQ59_Single_Colony_TilesScan.lif_3dTimeScan_17...
# 27           0.417866  EQ59_Single_Colony_TilesScan.lif_3dTimeScan_17...
# 28           0.428501  EQ59_Single_Colony_TilesScan.lif_3dTimeScan_17...
# 29           0.447408  EQ59_Single_Colony_TilesScan.lif_3dTimeScan_17...
# 30           0.457746  EQ59_Single_Colony_TilesScan.lif_3dTimeScan_17...
# 31           0.474325  EQ59_Single_Colony_TilesScan.lif_3dTimeScan_17...
# 32           0.493695  EQ59_Single_Colony_TilesScan.lif_3dTimeScan_17...
# 33           0.511032  EQ59_Single_Colony_TilesScan.lif_3dTimeScan_17...
# 34           0.531099  EQ59_Single_Colony_TilesScan.lif_3dTimeScan_17...
# 35           0.551865  EQ59_Single_Colony_TilesScan.lif_3dTimeScan_17...
# 36           0.562129  EQ59_Single_Colony_TilesScan.lif_3dTimeScan_17...
# 37           0.581591  EQ59_Single_Colony_TilesScan.lif_3dTimeScan_17...
# 38           0.602808  EQ59_Single_Colony_TilesScan.lif_3dTimeScan_17...
# 39           0.624484  EQ59_Single_Colony_TilesScan.lif_3dTimeScan_17...
# 40           0.630144  EQ59_Single_Colony_TilesScan.lif_3dTimeScan_17...
# 41           0.670010  EQ59_Single_Colony_TilesScan.lif_3dTimeScan_17...
# 42           0.676610  EQ59_Single_Colony_TilesScan.lif_3dTimeScan_17...
# 43           0.698019  EQ59_Single_Colony_TilesScan.lif_3dTimeScan_17...
# 44           0.712668  EQ59_Single_Colony_TilesScan.lif_3dTimeScan_17...
# 45           0.736920  EQ59_Single_Colony_TilesScan.lif_3dTimeScan_17...
# 46           0.742537  EQ59_Single_Colony_TilesScan.lif_3dTimeScan_17...
# 47           0.773011  EQ59_Single_Colony_TilesScan.lif_3dTimeScan_17...
# 48           0.785140  EQ59_Single_Colony_TilesScan.lif_3dTimeScan_17...
# 49           0.800589  EQ59_Single_Colony_TilesScan.lif_3dTimeScan_17...
# 50           0.818590  EQ59_Single_Colony_TilesScan.lif_3dTimeScan_17...
# 51           0.835252  EQ59_Single_Colony_TilesScan.lif_3dTimeScan_17...
# 52           0.857296  EQ59_Single_Colony_TilesScan.lif_3dTimeScan_17...
# 53           0.872919  EQ59_Single_Colony_TilesScan.lif_3dTimeScan_17...
# 54           0.888295  EQ59_Single_Colony_TilesScan.lif_3dTimeScan_17...
# 55           0.905213  EQ59_Single_Colony_TilesScan.lif_3dTimeScan_17...
# 56           0.923156  EQ59_Single_Colony_TilesScan.lif_3dTimeScan_17...
# 57           0.956636  EQ59_Single_Colony_TilesScan.lif_3dTimeScan_17...
# 58           0.952848  EQ59_Single_Colony_TilesScan.lif_3dTimeScan_17...
#
#       acq_type                                        base_folder
# Tp_id
# 7         xyzt  D:/Tolga/Colony Images/EQ59_Single_Colony_Tile...
# 8         xyzt  D:/Tolga/Colony Images/EQ59_Single_Colony_Tile...
# 9         xyzt  D:/Tolga/Colony Images/EQ59_Single_Colony_Tile...
# 10        xyzt  D:/Tolga/Colony Images/EQ59_Single_Colony_Tile...
# 11        xyzt  D:/Tolga/Colony Images/EQ59_Single_Colony_Tile...
# 12        xyzt  D:/Tolga/Colony Images/EQ59_Single_Colony_Tile...
# 13        xyzt  D:/Tolga/Colony Images/EQ59_Single_Colony_Tile...
# 14        xyzt  D:/Tolga/Colony Images/EQ59_Single_Colony_Tile...
# 15        xyzt  D:/Tolga/Colony Images/EQ59_Single_Colony_Tile...
# 16        xyzt  D:/Tolga/Colony Images/EQ59_Single_Colony_Tile...
# 17        xyzt  D:/Tolga/Colony Images/EQ59_Single_Colony_Tile...
# 18        xyzt  D:/Tolga/Colony Images/EQ59_Single_Colony_Tile...
# 19        xyzt  D:/Tolga/Colony Images/EQ59_Single_Colony_Tile...
# 20        xyzt  D:/Tolga/Colony Images/EQ59_Single_Colony_Tile...
# 21        xyzt  D:/Tolga/Colony Images/EQ59_Single_Colony_Tile...
# 22        xyzt  D:/Tolga/Colony Images/EQ59_Single_Colony_Tile...
# 23        xyzt  D:/Tolga/Colony Images/EQ59_Single_Colony_Tile...
# 24        xyzt  D:/Tolga/Colony Images/EQ59_Single_Colony_Tile...
# 25        xyzt  D:/Tolga/Colony Images/EQ59_Single_Colony_Tile...
# 26        xyzt  D:/Tolga/Colony Images/EQ59_Single_Colony_Tile...
# 27        xyzt  D:/Tolga/Colony Images/EQ59_Single_Colony_Tile...
# 28        xyzt  D:/Tolga/Colony Images/EQ59_Single_Colony_Tile...
# 29        xyzt  D:/Tolga/Colony Images/EQ59_Single_Colony_Tile...
# 30        xyzt  D:/Tolga/Colony Images/EQ59_Single_Colony_Tile...
# 31        xyzt  D:/Tolga/Colony Images/EQ59_Single_Colony_Tile...
# 32        xyzt  D:/Tolga/Colony Images/EQ59_Single_Colony_Tile...
# 33        xyzt  D:/Tolga/Colony Images/EQ59_Single_Colony_Tile...
# 34        xyzt  D:/Tolga/Colony Images/EQ59_Single_Colony_Tile...
# 35        xyzt  D:/Tolga/Colony Images/EQ59_Single_Colony_Tile...
# 36        xyzt  D:/Tolga/Colony Images/EQ59_Single_Colony_Tile...
# 37        xyzt  D:/Tolga/Colony Images/EQ59_Single_Colony_Tile...
# 38        xyzt  D:/Tolga/Colony Images/EQ59_Single_Colony_Tile...
# 39        xyzt  D:/Tolga/Colony Images/EQ59_Single_Colony_Tile...
# 40        xyzt  D:/Tolga/Colony Images/EQ59_Single_Colony_Tile...
# 41        xyzt  D:/Tolga/Colony Images/EQ59_Single_Colony_Tile...
# 42        xyzt  D:/Tolga/Colony Images/EQ59_Single_Colony_Tile...
# 43        xyzt  D:/Tolga/Colony Images/EQ59_Single_Colony_Tile...
# 44        xyzt  D:/Tolga/Colony Images/EQ59_Single_Colony_Tile...
# 45        xyzt  D:/Tolga/Colony Images/EQ59_Single_Colony_Tile...
# 46        xyzt  D:/Tolga/Colony Images/EQ59_Single_Colony_Tile...
# 47        xyzt  D:/Tolga/Colony Images/EQ59_Single_Colony_Tile...
# 48        xyzt  D:/Tolga/Colony Images/EQ59_Single_Colony_Tile...
# 49        xyzt  D:/Tolga/Colony Images/EQ59_Single_Colony_Tile...
# 50        xyzt  D:/Tolga/Colony Images/EQ59_Single_Colony_Tile...
# 51        xyzt  D:/Tolga/Colony Images/EQ59_Single_Colony_Tile...
# 52        xyzt  D:/Tolga/Colony Images/EQ59_Single_Colony_Tile...
# 53        xyzt  D:/Tolga/Colony Images/EQ59_Single_Colony_Tile...
# 54        xyzt  D:/Tolga/Colony Images/EQ59_Single_Colony_Tile...
# 55        xyzt  D:/Tolga/Colony Images/EQ59_Single_Colony_Tile...
# 56        xyzt  D:/Tolga/Colony Images/EQ59_Single_Colony_Tile...
# 57        xyzt  D:/Tolga/Colony Images/EQ59_Single_Colony_Tile...
# 58        xyzt  D:/Tolga/Colony Images/EQ59_Single_Colony_Tile...

# %%
# Select a timepoint
tpid = 29
timepoint = combined_df.loc[tpid]

base_folder = timepoint["base_folder"]
acq_name = timepoint["acq_name"]
acq_type = timepoint["acq_type"]
tix = timepoint["tix"]

# %%
# Read metadata for the chosen timepoint, and get the possible tstr and zstr values
metadata_folder = base_folder + "Metadata/"

tree = ET.parse(metadata_folder + f"{acq_name}_Properties.xml")    # xml tree of the current stage position
root = tree.getroot()           # root of the xml tree
image = root[0]

image_description = None
img_name = ""
xsz = ysz = zsz = ssz = tsz = -1
xvoxel = yvoxel = zvoxel = -1
for child in image:
    if child.tag == "ImageDescription":
        image_description = child
        for gchild in image_description:
            if gchild.tag == "Name":    # Name of the image
                img_name = gchild.text
            elif gchild.tag == "Dimensions":     # x,y,z,stage,t dimensions
                # Run through each deminson description
                for ggchild in gchild:
                    if ggchild.tag == "DimensionDescription":   # Check for tag
                        if ggchild.get("DimID") == "X":
                            xsz = int(ggchild.get("NumberOfElements"))
                            xvoxel = np.double(ggchild.get("Voxel"))
                        elif ggchild.get("DimID") == "Y":
                            ysz = int(ggchild.get("NumberOfElements"))
                            yvoxel = np.double(ggchild.get("Voxel"))
                        elif ggchild.get("DimID") == "Z":
                            zsz = int(ggchild.get("NumberOfElements"))
                            zvoxel = np.double(ggchild.get("Voxel"))
                        elif ggchild.get("DimID") == "Stage":
                            ssz = int(ggchild.get("NumberOfElements"))
                            svoxel = np.double(ggchild.get("Voxel"))
                        elif ggchild.get("DimID") == "T":
                            tsz = int(ggchild.get("NumberOfElements"))
                            # Note: tvoxel is not used!!
                            # Each image has its own timestamp data

# Check if all the values were updated
if tsz == -1:
    if acq_type == "xyzt":
        print("ERROR! Something is wrong. Couldn't find the number of timepoints")
    elif acq_type == "xyz":
        tsz = 1
    else:
        print("Undefined acq_type")

if zsz == -1:
    print("ERROR! Cannot find the z-stacks information. Check the filepath.")

# %% [markdown]
# ## Read the chosen boxfiltered image in cv2

# %%
# Select a z-position
zix = 150
# Select a channel str
channel_str = "ch00"

zstr = None
if zsz > 100:
    zstr = "z%03d" % (zix)
elif zsz > 9:
    zstr = "z%02d" % (zix)

tstr = None
if acq_type == "xyzt":
    if tsz > 10:
        tstr = "t%02d" % (tix)
    elif tsz > 0:
        tstr = "t%01d" % (tix)

if tstr == None:
    boxfiltered_path = f"{base_folder}{channel_str}/Boxfiltered/{acq_name}_Boxfiltered_{zstr}_{channel_str}.tif"
else:
    if tpid < 10:
        boxfiltered_path = f"{base_folder}{channel_str}/Boxfiltered/3dTimeScan_12h_init_Boxfiltered_{tstr}_{zstr}_{channel_str}.tif"
    else:
        boxfiltered_path = f"{base_folder}{channel_str}/Boxfiltered/3dTimeScan_17h_init_long_Boxfiltered_{tstr}_{zstr}_{channel_str}.tif"
#     boxfiltered_path = f"{base_folder}{channel_str}/Boxfiltered/{acq_name}_Boxfiltered_{tstr}_{zstr}_{channel_str}.tif"

filtered = cv2.imread(boxfiltered_path, cv2.IMREAD_GRAYSCALE)
fig,ax = plt.subplots()

ax.imshow(cv2.resize(filtered/normalization_const, (512,512)), vmin=0, vmax=1)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
boxfiltered_path
# Out:
# 'D:/Tolga/Colony Images/EQ59_Single_Colony_TilesScan.lif/3dTimeScan_17h_init_long/ch00/Boxfiltered/EQ59_Single_Colony_TilesScan.lif_3dTimeScan_17h_init_long_Boxfiltered_t19_z050_ch00.tif'

# %% [markdown]
# ## Now, for the given timepoint, save the normalized filtered movie of z-stacks after downsampling to (512,512)

# %%
# Normalization constant, the maximum filtered counts
normalization_const = timepoint["max_filtered_counts"].max()

# Select a timepoint
for tpid in combined_df.index:
    timepoint = combined_df.loc[tpid]

    base_folder = timepoint["base_folder"]
    acq_name = timepoint["acq_name"]
    acq_type = timepoint["acq_type"]
    tix = timepoint["tix"]
    
    # Read metadata for the chosen timepoint, and get the possible tstr and zstr values
    metadata_folder = base_folder + "Metadata/"

    tree = ET.parse(metadata_folder + f"{acq_name}_Properties.xml")    # xml tree of the current stage position
    root = tree.getroot()           # root of the xml tree
    image = root[0]

    image_description = None
    img_name = ""
    xsz = ysz = zsz = ssz = tsz = -1
    xvoxel = yvoxel = zvoxel = -1
    for child in image:
        if child.tag == "ImageDescription":
            image_description = child
            for gchild in image_description:
                if gchild.tag == "Name":    # Name of the image
                    img_name = gchild.text
                elif gchild.tag == "Dimensions":     # x,y,z,stage,t dimensions
                    # Run through each deminson description
                    for ggchild in gchild:
                        if ggchild.tag == "DimensionDescription":   # Check for tag
                            if ggchild.get("DimID") == "X":
                                xsz = int(ggchild.get("NumberOfElements"))
                                xvoxel = np.double(ggchild.get("Voxel"))
                            elif ggchild.get("DimID") == "Y":
                                ysz = int(ggchild.get("NumberOfElements"))
                                yvoxel = np.double(ggchild.get("Voxel"))
                            elif ggchild.get("DimID") == "Z":
                                zsz = int(ggchild.get("NumberOfElements"))
                                zvoxel = np.double(ggchild.get("Voxel"))
                            elif ggchild.get("DimID") == "Stage":
                                ssz = int(ggchild.get("NumberOfElements"))
                                svoxel = np.double(ggchild.get("Voxel"))
                            elif ggchild.get("DimID") == "T":
                                tsz = int(ggchild.get("NumberOfElements"))
                                # Note: tvoxel is not used!!
                                # Each image has its own timestamp data

    # Check if all the values were updated
    if tsz == -1:
        if acq_type == "xyzt":
            print("ERROR! Something is wrong. Couldn't find the number of timepoints")
        elif acq_type == "xyz":
            tsz = 1
        else:
            print("Undefined acq_type")

    if zsz == -1:
        print("ERROR! Cannot find the z-stacks information. Check the filepath.")
    
    
    # The suffix defining the timepoint as given by the microscope tilescan images
    tstr = None
    if acq_type == "xyzt":
        if tsz > 10:
            tstr = "t%02d" % (tix)
        elif tsz > 0:
            tstr = "t%01d" % (tix)

    # Suffix that comes to the end of the video filename
    tpstr = "Tp" + str(tpid)


    # Select a channel str
    channel_str = "ch00"
    # Video path to write
    video_path = folder + exp_name + "/Videos_unmarked/" + exp_name + "_" + tpstr + ".avi"
    # Video writer object
    out = cv2.VideoWriter(video_path, cv2.VideoWriter_fourcc(*'DIVX'), 4, (512,512))
    # Select a z-position
    for zix in range(zsz):
        print("tix = %d/%d, zix = %d/%d" % (tix, tsz, zix, zsz), end="   \r", flush=True)
        zstr = None
        if zsz > 100:
            zstr = "z%03d" % (zix)
        elif zsz > 9:
            zstr = "z%02d" % (zix)

        if tstr == None:
            boxfiltered_path = base_folder + channel_str + "/Boxfiltered/" + acq_name + "_" + "Boxfiltered" + "_" + zstr + "_" + channel_str + ".tif"
        else:
            if tpid < 10:
                boxfiltered_path = f"{base_folder}{channel_str}/Boxfiltered/3dTimeScan_12h_init_Boxfiltered_{tstr}_{zstr}_{channel_str}.tif"
            else:
                boxfiltered_path = f"{base_folder}{channel_str}/Boxfiltered/3dTimeScan_17h_init_long_Boxfiltered_{tstr}_{zstr}_{channel_str}.tif"

#             boxfiltered_path = base_folder + channel_str + "/Boxfiltered/" + acq_name + "_" + "Boxfiltered" + "_" + tstr + "_" + zstr + "_" + channel_str + ".tif"

        # Read boxfiltered image
        filtered = cv2.imread(boxfiltered_path)
        # Normalize the filtered image with the normalization constant obtained from the maximum filtered count
        normalized = np.uint8(filtered/normalization_const*255)
        # Resize the image for outputting video
        resized = cv2.resize(normalized, (512,512))

        out.write(resized)

    out.release()
# Out:
# tix = 48/49, zix = 234/235

# %% [markdown]
# ## Mark the videos with a scalebar and z-value

# %%
# Go through each timepoint and each frame to collect the pixel and their locations that exceeds the threshold
def get_image_sequence(video_path):
    # Video capture object
    vidcap = cv2.VideoCapture(video_path)

    # Frame properties
    frame_count = int(vidcap.get(cv2.CAP_PROP_FRAME_COUNT))
    frame_height = int(vidcap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    frame_width = int(vidcap.get(cv2.CAP_PROP_FRAME_WIDTH))

    img_seq = np.zeros((frame_height, frame_width, frame_count), dtype=np.uint8)
    for fix in range(frame_count):
        # Read frmae
        success,frame = vidcap.read()
        # Convert to grayscale
        frame_gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        img_seq[:,:,fix] = frame_gray
        
    return img_seq

# %%
dim_desc
# Out:
# {'img_name': '3dTimeScan_12h_init',
#  'xsz': 1024,
#  'xvoxel': 0.454,
#  'xunit': 'um',
#  'ysz': 1024,
#  'yvoxel': 0.454,
#  'yunit': 'um',
#  'zsz': 168,
#  'zvoxel': -0.006,
#  'zunit': 'mm',
#  'ssz': 36,
#  'svoxel': None,
#  'tsz': 9}

# %%
# Select a timepoint
for tpid in combined_df.index:
    if tpid < 7:
        continue
    timepoint = combined_df.loc[tpid]

    base_folder = timepoint["base_folder"]
    acq_name = timepoint["acq_name"]
    acq_type = timepoint["acq_type"]
    tix = timepoint["tix"]
    
    # Read metadata for the chosen timepoint, and get the possible tstr and zstr values
    metadata_folder = base_folder + "Metadata/"

    tree = ET.parse(metadata_folder + f"{acq_name}_Properties.xml")    # xml tree of the current stage position
    root = tree.getroot()           # root of the xml tree
    image = root[0]
    # Image dimension description
    dim_desc = cm.collectImageDim(image)
    scale_vid = int(512/(dim_desc["xsz"]*np.sqrt(dim_desc["ssz"])))

    image_description = None
    img_name = ""
    xsz = ysz = zsz = ssz = tsz = -1
    xvoxel = yvoxel = zvoxel = -1
    for child in image:
        if child.tag == "ImageDescription":
            image_description = child
            for gchild in image_description:
                if gchild.tag == "Name":    # Name of the image
                    img_name = gchild.text
                elif gchild.tag == "Dimensions":     # x,y,z,stage,t dimensions
                    # Run through each deminson description
                    for ggchild in gchild:
                        if ggchild.tag == "DimensionDescription":   # Check for tag
                            if ggchild.get("DimID") == "X":
                                xsz = int(ggchild.get("NumberOfElements"))
                                xvoxel = np.double(ggchild.get("Voxel"))
                            elif ggchild.get("DimID") == "Y":
                                ysz = int(ggchild.get("NumberOfElements"))
                                yvoxel = np.double(ggchild.get("Voxel"))
                            elif ggchild.get("DimID") == "Z":
                                zsz = int(ggchild.get("NumberOfElements"))
                                zvoxel = np.double(ggchild.get("Voxel"))
                            elif ggchild.get("DimID") == "Stage":
                                ssz = int(ggchild.get("NumberOfElements"))
                                svoxel = np.double(ggchild.get("Voxel"))
                            elif ggchild.get("DimID") == "T":
                                tsz = int(ggchild.get("NumberOfElements"))
                                # Note: tvoxel is not used!!
                                # Each image has its own timestamp data

    # Check if all the values were updated
    if tsz == -1:
        if acq_type == "xyzt":
            print("ERROR! Something is wrong. Couldn't find the number of timepoints")
        elif acq_type == "xyz":
            tsz = 1
        else:
            print("Undefined acq_type")

    if zsz == -1:
        print("ERROR! Cannot find the z-stacks information. Check the filepath.")
    
    
    # The suffix defining the timepoint as given by the microscope tilescan images
    tstr = None
    if acq_type == "xyzt":
        if tsz > 10:
            tstr = "t%02d" % (tix)
        elif tsz > 0:
            tstr = "t%01d" % (tix)

    # Suffix that comes to the end of the video filename
    tpstr = "Tp" + str(tpid)


    # Select a channel str
    channel_str = "ch00"
    # Video path to write
    video_out_path = folder + exp_name + "/Videos_marked/" + exp_name + "_" + tpstr + ".avi"
    video_in_path  = folder + exp_name + "/Videos_unmarked/" + exp_name + "_" + tpstr + ".avi"
    img_seq = get_image_sequence(video_in_path)
    # Video writer object
    out = cv2.VideoWriter(video_out_path, cv2.VideoWriter_fourcc(*'DIVX'), 4, (512,512))
    # Select a z-position
    for zix in range(zsz):
        img = img_seq[:,:,zix].astype(np.uint8)
        print("tix = %d/%d, zix = %d/%d" % (tix, tsz, zix, zsz), end="   \r", flush=True)
        zstr = None
        if zsz > 100:
            zstr = "z%03d" % (zix)
        elif zsz > 9:
            zstr = "z%02d" % (zix)

        # Scale bar
        scalebar_length = 500   # in um
        bar_start_coor = (50,440)
        bar_end_coor = (int(50 + scalebar_length/dim_desc["xvoxel"]*scale_vid),450)
        bar_thickness = -1
        bar_color = (255,255,255)
        cv2.rectangle(img, bar_start_coor, bar_end_coor, bar_color, bar_thickness)
        
        text_x = int(bar_start_coor[0])
        text_y = int((bar_start_coor[1]+bar_end_coor[1])/2 + 30)
        cv2.putText(img,"%d %s" % (scalebar_length, dim_desc["xunit"]), (text_x,text_y), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2)
        
        zval_x = 260
        zval_y = 50
        z_str = "z=%.3f%s" % (zix*dim_desc["zvoxel"]/1e3, "mm")
        cv2.putText(img, z_str, (zval_x, zval_y), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2)

        out.write(img)

    out.release()
# Out:
# tix = 5/49, zix = 234/235
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-58-96a70b672d06> in <module>
#      13     metadata_folder = base_folder + "Metadata/"
#      14
# ---> 15     tree = ET.parse(metadata_folder + f"{acq_name}_Properties.xml")    # xml tree of the current stage position
#      16     root = tree.getroot()           # root of the xml tree
#      17     image = root[0]
#
# ~\miniconda3\lib\xml\etree\ElementTree.py in parse(source, parser)
#    1200     """
#    1201     tree = ElementTree()
# -> 1202     tree.parse(source, parser)
#    1203     return tree
#    1204
#
# ~\miniconda3\lib\xml\etree\ElementTree.py in parse(self, source, parser)
#     593                     # It can be used to parse the whole source without feeding
#     594                     # it with chunks.
# --> 595                     self._root = parser._parse_whole(source)
#     596                     return self._root
#     597             while True:
#
# KeyboardInterrupt:

# %%
fig,ax = plt.subplots()
ax.imshow(img)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
